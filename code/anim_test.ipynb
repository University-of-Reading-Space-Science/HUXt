# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
r, dr = np.linspace(1, 10, 100, retstep=True)

twopi = 2.0 * np.pi
Nt = 128
dt1 = twopi / Nt
t_min = dt1 / 2.0
t_max = twopi - (dt1 / 2.0)
t, dt = np.linspace(t_min, t_max, Nt, retstep=True)

tg, rg = np.meshgrid(t, r)
f = np.exp(-(rg/5)**2) * np.sin(tg)

# %%
fig, ax = plt.subplots(figsize=(7, 7), subplot_kw={"projection":"polar"})
ax.contourf(tg, rg, f, levels=50)

# %%
pad = tg[:,0].reshape((tg.shape[0],1)) + twopi
tg1 = np.concatenate((tg,pad),axis=1)
pad = rg[:,0].reshape((rg.shape[0],1))
rg1 = np.concatenate((rg,pad),axis=1)
pad = f[:,0].reshape((f.shape[0],1))
f1 = np.concatenate((f,pad),axis=1)

fig, ax = plt.subplots(figsize=(7, 7), subplot_kw={"projection":"polar"})
ax.contourf(tg1, rg1, f1, levels=50)
