# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import HUXt as H
import astropy.units as u
# %matplotlib inline

# %%
# Set up HUXt1D to run a 5 day simulation of Carrington rotation 2000, and output model data every 4 timesteps (about 35min)
cr_num = 2000
lon = 0.0
model1 = H.HUXt1D(cr_num, lon=lon, simtime=5, dt_scale=4)

# Get a list of different CMEs with random launch longitudes and times
cme_list=[]
n_cme = 5
launch_lons = [0 for i in range(n_cme)]
daysec = 86400
launch_times = [(0.25 + i*4/n_cme)*daysec for i in range(n_cme)]
               
for lon, t_launch in zip(launch_lons, launch_times):
    print(lon, t_launch)
    cme = H.ConeCME(t_launch=t_launch, longitude=lon, width=30, v=1000, thickness=5)
    cme_list.append(cme)
    
# Run HUXt for these cmes, save to file 
tag = 'test'
model1.solve(cme_list, save=True, tag=tag ) 

# Plot a radial slice
for t in np.arange(0.5, 5.0, 0.5):
    t_obs = t*u.day               
    model1.plot_radial(t_obs, field='both', save=True, tag=tag)
# Plot a timeseries at near 1AU.
r_obs = 215*u.solRad
model1.plot_timeseries(r_obs, field='both', save=True, tag=tag)
r_obs = 50*u.solRad
model1.plot_timeseries(r_obs, field='both', save=True, tag=tag)
# Out:
# 0 21600.0
# 0 90720.0
# 0 159840.0
# 0 228960.0
# 0 298080.0
# ...
# (<Figure size 1008x504 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x200f5c4f710>)

# %%
# Set up HUXt2D to run a simulation with the same parameters.
model2 = H.HUXt2D(cr_num, simtime=5, dt_scale=4)

# Get a list of different CMEs with random launch longitudes and times

# Run HUXt for these cmes, save to file 
tag = 'test'
model2.solve(cme_list, save=True, tag=tag) 

# Make an MP4 of the solution with CME
model2.animate('cme', tag)

# %%
# Show both solutions match along the selected longitude

# Find index of the selected longitude, a time, and approx 1AU.
lon = 30
id_lon = np.argmin(np.abs(model2.lon.to(u.deg).value - lon))
id_t = 100
id_r = np.argmin(np.abs(model2.r.value - 215))

fig, ax = plt.subplots(1,2, figsize=(12.5,6.25))
ax[0].plot(model1.r, model1.v_grid_cme[id_t, :], 'k-', label='1D')
ax[0].plot(model2.r, model2.v_grid_cme[id_t, :, id_lon], 'r--', label='2D')

ax[1].plot(model1.time_out.to(u.day), model1.v_grid_cme[:, id_r], 'k-', label='1D')
ax[1].plot(model2.time_out.to(u.day), model2.v_grid_cme[:, id_r, id_lon], 'r--', label='2D')

for a in ax:
    a.legend()
    a.set_ylim(200,1200)
    a.set_ylabel('Solar Wind Speed (km/s)')
    
ax[0].set_xlabel('Radial distance (solar radii)')
ax[1].set_xlabel('Time (days)')
ax[1].yaxis.tick_right()
ax[1].yaxis.set_label_position("right")
    
fig.subplots_adjust(left=0.05, bottom=0.05, right=0.95, top=0.95, wspace=0.025)
