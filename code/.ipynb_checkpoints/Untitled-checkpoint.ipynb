# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from moviepy.video.io.bindings import mplfig_to_npimage
import moviepy.editor as mpy
import HUXt as H
import astropy.units as u
import h5py
# %matplotlib inline

# %%
#vb, cme, model = H.load_cone_cme_run('C:\\Users\\yq904481\\PycharmProjects\\HUXt\\data\\HUXt2DCME_test.hdf5')
#f = h5py.File('C:\\Users\\yq904481\\PycharmProjects\\HUXt\\data\\HUXt2DCME_test.hdf5', 'r')

# %%
v_boundary = np.ones(128) * 400 * u.km/u.s
v_boundary[10:20] = v_boundary[10:20] * 2.0
v_boundary[60:80] = v_boundary[60:80] * 2.0
cme = H.ConeCME(t_launch=1000, longitude=90.0, width=30, v=1000, thickness=10)
cone_model = H.HUXt2DCME(dt_scale=4)
cone_model.solve_cone_cme(v_boundary, cme, save=True, tag='test2')

# %% [raw]
# mpl.rc("font", size=13)
# #mpl.rc("axes", labelsize=14)
# #mpl.rc("ytick", labelsize=13)
# #mpl.rc("xtick", labelsize=13)
# #mpl.rc("legend", fontsize=13)
#
# t=0
# levels = np.arange(250, 875, 25)
# fig, ax = plt.subplots(figsize=(7,7), subplot_kw={"projection":"polar"})
# cnt = ax.contourf(cone_model.lon_grid.value, cone_model.r_grid.value, cone_model.v_grid_cme.value[t, :, :], levels=levels)
# ax.set_ylim(0, 230)
# ax.set_yticklabels([])
# fig.subplots_adjust(left=0.05, bottom=0.2, right=0.95, top=0.95)
#
# # Add colorbar
# pos = ax.get_position()
# dw = 0.005
# dh = 0.075
# left = pos.x0 + dw
# bottom = pos.y0 - dh
# wid = pos.width - 2 * dw
# cbaxes = fig.add_axes([left, bottom, wid, 0.03])
# cbar1 = fig.colorbar(cnt, cax=cbaxes, orientation='horizontal')
# cbar1.ax.set_xlabel("Solar Wind Speed (km/s)")
#
# # Add label
# time_label = "Time: {:3.2f} days".format(cone_model.time_out[t].to(u.day).value)
# ax.set_title(time_label, position=(0.8, -0.05))
#
#
#
# fig.savefig('test.png')

# %%
tag = 'test_run'
cme_model.plot_frame(100, save=True,tag=tag)

# %%
cme_model.animate_plot(tag)

# %% [raw]
# To do list:
# Need:
# Format contour plot
# Close gap in contour data
# Fix CME 0 longitude crossing error
# Nice:
# Add in multiple CMEs?
# CME tracer field with advection?
